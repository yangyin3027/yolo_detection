# %%
import cv2
from utils import *
from yolo_detector import *
import random

# %%
yolo = YoloDetection()

videofile = './data/demoVideo.mp4'
cap = cv2.VideoCapture(videofile)
pre_frame_time, new_frame_time = 0, 0

while (cap.isOpened()):
    frameId = cap.get(1)
    ret, frame = cap.read()
    if not ret:
        break

    output = yolo.model(frame)[0]

    boxes = output.boxes.xyxy
    class_ids = output.boxes.cls
    scores = output.boxes.conf

    valid_idx = scores > 0.8
    boxes = boxes[valid_idx]
    class_ids = class_ids[valid_idx]
    scores = scores[valid_idx]

    colors = [(256,0, 0), (0,0,0), (0,256,0),(0,0,256)]
    random.shuffle(colors)
    colors = [colors[int(i%len(colors))] for i in class_ids]

    cls_names = [output.names[int(x)] for x in class_ids]
    labels = [f"{cls} {round(s.numpy()*100)}%"
                  for cls, s in zip(cls_names, scores)]

    for i in range(len(scores)):
        (x, y) = (int(boxes[i][0]), boxes[i][1])
        (x2, y2) = (boxes[i][2], boxes[i][3])
        color = colors[i]
        cv2.rectangle(frame, (int(x), int(y)),(int(x2), int(y2)), color,2)
        cv2.putText(frame, labels[i], (int(x), int(y-5)),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.5, color,2)

    cv2.imshow('new_frame', frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
cv2.waitKey(1)
# Out:
# 0: 640x384 2 persons, 1 bowl, 105.9ms
# Speed: 1.8ms preprocess, 105.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 bowl, 113.3ms
# Speed: 2.5ms preprocess, 113.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 bowl, 94.3ms
# Speed: 1.5ms preprocess, 94.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 persons, 99.6ms
# Speed: 1.3ms preprocess, 99.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 persons, 91.9ms
# Speed: 1.6ms preprocess, 91.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 102.6ms
# Speed: 1.4ms preprocess, 102.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 97.5ms
# Speed: 1.9ms preprocess, 97.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 100.1ms
# Speed: 1.4ms preprocess, 100.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 1 bottle, 1 bowl, 1 dining table, 91.7ms
# Speed: 1.5ms preprocess, 91.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 2 bottles, 1 bowl, 93.6ms
# Speed: 1.5ms preprocess, 93.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 2 bottles, 1 bowl, 112.3ms
# Speed: 1.7ms preprocess, 112.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 1 bottle, 2 bowls, 1 dining table, 98.5ms
# Speed: 1.4ms preprocess, 98.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 1 bottle, 2 bowls, 95.6ms
# Speed: 1.5ms preprocess, 95.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 1 bottle, 2 bowls, 1 potted plant, 95.5ms
# Speed: 1.5ms preprocess, 95.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 1 bottle, 2 bowls, 103.7ms
# Speed: 1.5ms preprocess, 103.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 1 bottle, 1 bowl, 94.9ms
# Speed: 1.8ms preprocess, 94.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 1 bottle, 1 bowl, 95.0ms
# Speed: 1.7ms preprocess, 95.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 1 bottle, 2 bowls, 99.7ms
# Speed: 1.9ms preprocess, 99.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 1 bottle, 3 bowls, 1 dining table, 100.2ms
# Speed: 1.4ms preprocess, 100.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 3 bowls, 3 dining tables, 98.7ms
# Speed: 1.6ms preprocess, 98.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 bottle, 1 wine glass, 2 bowls, 2 dining tables, 98.0ms
# Speed: 1.7ms preprocess, 98.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 2 bowls, 2 dining tables, 94.6ms
# Speed: 1.9ms preprocess, 94.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 2 bowls, 2 dining tables, 88.5ms
# Speed: 1.6ms preprocess, 88.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 bottle, 1 cup, 2 bowls, 1 dining table, 92.8ms
# Speed: 1.4ms preprocess, 92.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 2 bowls, 2 dining tables, 97.9ms
# Speed: 1.6ms preprocess, 97.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 bottles, 2 bowls, 1 dining table, 101.8ms
# Speed: 1.3ms preprocess, 101.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 2 bowls, 1 dining table, 91.3ms
# Speed: 1.4ms preprocess, 91.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 2 bowls, 2 dining tables, 87.5ms
# Speed: 1.8ms preprocess, 87.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 2 bowls, 2 dining tables, 97.3ms
# Speed: 1.6ms preprocess, 97.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 bottles, 1 dining table, 92.7ms
# Speed: 1.5ms preprocess, 92.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 bottles, 1 bowl, 1 dining table, 94.4ms
# Speed: 1.5ms preprocess, 94.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 cup, 1 bowl, 1 dining table, 85.9ms
# Speed: 1.3ms preprocess, 85.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 wine glass, 1 bowl, 1 dining table, 108.9ms
# Speed: 1.5ms preprocess, 108.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 1 dining table, 97.9ms
# Speed: 1.7ms preprocess, 97.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 1 dining table, 95.9ms
# Speed: 1.5ms preprocess, 95.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 bowl, 1 apple, 2 dining tables, 107.9ms
# Speed: 1.7ms preprocess, 107.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 bowl, 2 dining tables, 105.5ms
# Speed: 1.4ms preprocess, 105.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 bowl, 1 dining table, 93.3ms
# Speed: 1.7ms preprocess, 93.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 bowl, 2 dining tables, 108.7ms
# Speed: 1.5ms preprocess, 108.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 cup, 1 bowl, 95.8ms
# Speed: 1.5ms preprocess, 95.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 cup, 1 bowl, 95.4ms
# Speed: 1.1ms preprocess, 95.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 bowl, 1 apple, 90.5ms
# Speed: 1.7ms preprocess, 90.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 cup, 1 bowl, 2 dining tables, 95.0ms
# Speed: 1.8ms preprocess, 95.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 cup, 2 bowls, 1 apple, 2 dining tables, 92.0ms
# Speed: 1.4ms preprocess, 92.0ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 cup, 1 bowl, 93.2ms
# Speed: 1.5ms preprocess, 93.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 bowl, 1 dining table, 97.2ms
# Speed: 1.7ms preprocess, 97.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 bowl, 1 dining table, 93.8ms
# Speed: 1.5ms preprocess, 93.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 bowl, 2 dining tables, 88.6ms
# Speed: 1.5ms preprocess, 88.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 bowl, 1 dining table, 95.3ms
# Speed: 1.9ms preprocess, 95.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 2 dining tables, 94.4ms
# Speed: 1.7ms preprocess, 94.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 bowl, 2 dining tables, 91.3ms
# Speed: 1.5ms preprocess, 91.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 2 dining tables, 92.8ms
# Speed: 1.4ms preprocess, 92.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 2 dining tables, 90.8ms
# Speed: 1.8ms preprocess, 90.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 2 dining tables, 89.8ms
# Speed: 1.8ms preprocess, 89.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 2 dining tables, 1 cell phone, 101.0ms
# Speed: 1.6ms preprocess, 101.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 1 dining table, 93.6ms
# Speed: 1.5ms preprocess, 93.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 2 dining tables, 109.5ms
# Speed: 1.4ms preprocess, 109.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 1 dining table, 101.0ms
# Speed: 1.3ms preprocess, 101.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 1 dining table, 93.2ms
# Speed: 1.4ms preprocess, 93.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 1 dining table, 88.2ms
# Speed: 1.3ms preprocess, 88.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 3 dining tables, 92.2ms
# Speed: 1.2ms preprocess, 92.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 2 dining tables, 89.5ms
# Speed: 1.8ms preprocess, 89.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 2 dining tables, 93.1ms
# Speed: 1.3ms preprocess, 93.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 wine glass, 1 bowl, 2 dining tables, 88.8ms
# Speed: 1.3ms preprocess, 88.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 wine glass, 1 bowl, 2 dining tables, 98.0ms
# Speed: 1.4ms preprocess, 98.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 1 dining table, 88.6ms
# Speed: 1.6ms preprocess, 88.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 bottles, 1 bowl, 1 dining table, 97.0ms
# Speed: 1.7ms preprocess, 97.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 2 bottles, 1 bowl, 2 dining tables, 86.9ms
# Speed: 1.5ms preprocess, 86.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 bottles, 1 bowl, 1 dining table, 97.3ms
# Speed: 2.1ms preprocess, 97.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 bottles, 2 dining tables, 89.0ms
# Speed: 1.5ms preprocess, 89.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 3 persons, 3 bottles, 2 dining tables, 99.6ms
# Speed: 1.6ms preprocess, 99.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 5 bottles, 1 bowl, 1 dining table, 91.4ms
# Speed: 1.2ms preprocess, 91.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 3 bottles, 1 bowl, 2 dining tables, 93.5ms
# Speed: 1.5ms preprocess, 93.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 2 bowls, 1 dining table, 93.7ms
# Speed: 1.6ms preprocess, 93.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 2 bowls, 1 dining table, 94.1ms
# Speed: 1.6ms preprocess, 94.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bowl, 1 dining table, 84.7ms
# Speed: 1.6ms preprocess, 84.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 1 bowl, 1 dining table, 101.1ms
# Speed: 1.2ms preprocess, 101.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 1 bowl, 1 dining table, 103.5ms
# Speed: 1.6ms preprocess, 103.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 persons, 1 bowl, 1 dining table, 144.1ms
# Speed: 1.2ms preprocess, 144.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bowl, 1 dining table, 110.3ms
# Speed: 1.2ms preprocess, 110.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bowl, 1 dining table, 95.8ms
# Speed: 1.7ms preprocess, 95.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 1 bowl, 88.4ms
# Speed: 1.5ms preprocess, 88.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 1 bowl, 111.7ms
# Speed: 1.3ms preprocess, 111.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bowl, 1 dining table, 88.3ms
# Speed: 1.3ms preprocess, 88.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 2 bowls, 1 dining table, 98.9ms
# Speed: 1.4ms preprocess, 98.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 persons, 2 bowls, 1 dining table, 92.4ms
# Speed: 1.9ms preprocess, 92.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 persons, 2 bowls, 1 dining table, 86.2ms
# Speed: 1.7ms preprocess, 86.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 2 bowls, 1 dining table, 97.4ms
# Speed: 1.4ms preprocess, 97.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 2 bowls, 1 dining table, 94.6ms
# Speed: 1.5ms preprocess, 94.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 persons, 2 bowls, 1 dining table, 95.2ms
# Speed: 1.4ms preprocess, 95.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 8 persons, 2 bowls, 1 dining table, 91.0ms
# Speed: 1.7ms preprocess, 91.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 persons, 2 bowls, 1 dining table, 94.7ms
# Speed: 1.6ms preprocess, 94.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 persons, 2 bowls, 1 dining table, 94.4ms
# Speed: 1.7ms preprocess, 94.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 persons, 2 bowls, 1 dining table, 92.7ms
# Speed: 1.7ms preprocess, 92.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 persons, 2 bowls, 1 dining table, 94.2ms
# Speed: 1.7ms preprocess, 94.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 persons, 2 bowls, 1 dining table, 89.9ms
# Speed: 1.3ms preprocess, 89.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 persons, 2 bowls, 1 dining table, 87.9ms
# Speed: 1.6ms preprocess, 87.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 7 persons, 2 bowls, 1 dining table, 89.8ms
# Speed: 1.4ms preprocess, 89.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 persons, 2 bowls, 1 dining table, 93.5ms
# Speed: 1.6ms preprocess, 93.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 2 bowls, 1 dining table, 98.9ms
# Speed: 1.7ms preprocess, 98.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 2 bowls, 1 dining table, 99.4ms
# Speed: 1.3ms preprocess, 99.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 2 bowls, 1 dining table, 89.1ms
# Speed: 1.6ms preprocess, 89.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 2 bowls, 1 dining table, 87.0ms
# Speed: 1.6ms preprocess, 87.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 2 bowls, 1 dining table, 92.0ms
# Speed: 1.4ms preprocess, 92.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bottle, 2 bowls, 1 dining table, 86.2ms
# Speed: 1.6ms preprocess, 86.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 2 bowls, 1 dining table, 93.5ms
# Speed: 1.4ms preprocess, 93.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 2 bowls, 1 dining table, 87.4ms
# Speed: 1.5ms preprocess, 87.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bottle, 2 bowls, 1 dining table, 91.6ms
# Speed: 1.9ms preprocess, 91.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 2 bowls, 1 dining table, 88.9ms
# Speed: 1.5ms preprocess, 88.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 1 bottle, 2 bowls, 1 dining table, 94.5ms
# Speed: 1.4ms preprocess, 94.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bottle, 2 bowls, 1 dining table, 91.2ms
# Speed: 1.6ms preprocess, 91.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 1 bottle, 2 bowls, 1 dining table, 90.3ms
# Speed: 1.4ms preprocess, 90.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 2 bowls, 1 dining table, 95.8ms
# Speed: 1.5ms preprocess, 95.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 1 bottle, 2 bowls, 1 dining table, 90.7ms
# Speed: 1.3ms preprocess, 90.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 4 persons, 2 bowls, 1 dining table, 95.1ms
# Speed: 1.5ms preprocess, 95.1ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bottle, 1 bowl, 1 dining table, 94.2ms
# Speed: 1.3ms preprocess, 94.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bowl, 1 dining table, 93.3ms
# Speed: 1.7ms preprocess, 93.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 persons, 1 bottle, 1 bowl, 1 dining table, 93.6ms
# Speed: 1.6ms preprocess, 93.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 persons, 1 bottle, 1 bowl, 1 dining table, 93.3ms
# Speed: 1.4ms preprocess, 93.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 6 persons, 1 bowl, 1 dining table, 97.8ms
# Speed: 1.5ms preprocess, 97.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bowl, 1 dining table, 90.3ms
# Speed: 1.3ms preprocess, 90.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bowl, 1 dining table, 90.9ms
# Speed: 1.2ms preprocess, 90.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bottle, 2 bowls, 1 dining table, 86.5ms
# Speed: 1.3ms preprocess, 86.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bottle, 2 bowls, 1 dining table, 93.4ms
# Speed: 1.4ms preprocess, 93.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 5 persons, 1 bottle, 2 bowls, 1 dining table, 93.6ms
# Speed: 1.6ms preprocess, 93.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 spoon, 1 bowl, 94.2ms
# Speed: 1.6ms preprocess, 94.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 bowl, 87.3ms
# Speed: 2.1ms preprocess, 87.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 bowl, 1 dining table, 91.0ms
# Speed: 1.2ms preprocess, 91.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 bowl, 1 dining table, 87.3ms
# Speed: 1.3ms preprocess, 87.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 bowl, 1 dining table, 86.6ms
# Speed: 1.5ms preprocess, 86.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 bowl, 1 dining table, 92.5ms
# Speed: 1.4ms preprocess, 92.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 1 bowl, 1 dining table, 83.7ms
# Speed: 1.4ms preprocess, 83.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 bowl, 87.3ms
# Speed: 1.4ms preprocess, 87.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 fork, 1 knife, 1 spoon, 1 bowl, 109.4ms
# Speed: 1.6ms preprocess, 109.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 bowl, 90.4ms
# Speed: 1.5ms preprocess, 90.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 bowl, 87.7ms
# Speed: 1.7ms preprocess, 87.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 bowl, 91.1ms
# Speed: 1.4ms preprocess, 91.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 bowl, 1 dining table, 92.0ms
# Speed: 1.3ms preprocess, 92.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 dining table, 91.4ms
# Speed: 1.3ms preprocess, 91.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 dining table, 98.7ms
# Speed: 1.5ms preprocess, 98.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 dining table, 90.7ms
# Speed: 1.4ms preprocess, 90.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 dining table, 103.4ms
# Speed: 1.3ms preprocess, 103.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 dining table, 101.9ms
# Speed: 1.3ms preprocess, 101.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 bowl, 1 dining table, 87.2ms
# Speed: 1.4ms preprocess, 87.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 bowl, 1 dining table, 89.6ms
# Speed: 1.4ms preprocess, 89.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 bowl, 1 dining table, 89.3ms
# Speed: 1.3ms preprocess, 89.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 bowl, 1 dining table, 87.9ms
# Speed: 1.5ms preprocess, 87.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 bowl, 1 dining table, 87.8ms
# Speed: 1.7ms preprocess, 87.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 bowl, 1 dining table, 98.4ms
# Speed: 1.6ms preprocess, 98.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 bowl, 1 dining table, 90.1ms
# Speed: 1.4ms preprocess, 90.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 bowl, 1 dining table, 87.9ms
# Speed: 1.4ms preprocess, 87.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 bowl, 1 dining table, 97.8ms
# Speed: 1.5ms preprocess, 97.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 bowl, 1 dining table, 95.5ms
# Speed: 1.3ms preprocess, 95.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 dining table, 89.0ms
# Speed: 1.3ms preprocess, 89.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 knife, 1 dining table, 91.7ms
# Speed: 1.4ms preprocess, 91.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 bowl, 1 dining table, 92.7ms
# Speed: 1.4ms preprocess, 92.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 bowl, 1 dining table, 97.3ms
# Speed: 1.5ms preprocess, 97.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 bowl, 1 dining table, 93.0ms
# Speed: 1.4ms preprocess, 93.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 bowl, 1 dining table, 90.8ms
# Speed: 1.6ms preprocess, 90.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 bowl, 1 dining table, 90.5ms
# Speed: 1.7ms preprocess, 90.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 bowl, 1 dining table, 90.0ms
# Speed: 1.4ms preprocess, 90.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 1 bowl, 1 dining table, 91.6ms
# Speed: 1.5ms preprocess, 91.6ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 91.9ms
# Speed: 1.5ms preprocess, 91.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 88.0ms
# Speed: 1.7ms preprocess, 88.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 91.2ms
# Speed: 1.6ms preprocess, 91.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 89.7ms
# Speed: 1.7ms preprocess, 89.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 86.2ms
# Speed: 1.7ms preprocess, 86.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 91.7ms
# Speed: 1.6ms preprocess, 91.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 90.8ms
# Speed: 1.5ms preprocess, 90.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# -1

# %%
yolo = YoloDetection()
output = yolo.model('./data/aba.jpg')[0]
# Out:
# image 1/1 /Users/yangzn/Documents/AI_demo/yolo/data/aba.jpg: 448x640 8 persons, 113.7ms
# Speed: 2.3ms preprocess, 113.7ms inference, 0.9ms postprocess per image at shape (1, 3, 448, 640)

# %%
output.boxes
# Out:
# WARNING ⚠️ 'Boxes.boxes' is deprecated. Use 'Boxes.data' instead.
# ultralytics.engine.results.Boxes object with attributes:
#
# boxes: tensor([[323.3387,  46.2252, 500.4973, 403.0473,   0.9110,   0.0000],
#         [457.9577,  59.5703, 612.0000, 403.2654,   0.9068,   0.0000],
#         [ 45.9237, 110.9755, 153.7983, 404.2437,   0.8958,   0.0000],
#         [  0.0000,  13.6495,  94.6383, 400.6388,   0.8943,   0.0000],
#         [124.7054,  88.7559, 232.8170, 402.3645,   0.8831,   0.0000],
#         [224.5188,  64.2595, 333.3858, 402.9164,   0.8819,   0.0000],
#         [309.3857,  23.5012, 393.5341, 183.1679,   0.7933,   0.0000],
#         [172.3384,  42.0756, 244.6108, 181.9800,   0.7423,   0.0000]])
# cls: tensor([0., 0., 0., 0., 0., 0., 0., 0.])
# conf: tensor([0.9110, 0.9068, 0.8958, 0.8943, 0.8831, 0.8819, 0.7933, 0.7423])
# data: tensor([[323.3387,  46.2252, 500.4973, 403.0473,   0.9110,   0.0000],
#         [457.9577,  59.5703, 612.0000, 403.2654,   0.9068,   0.0000],
#         [ 45.9237, 110.9755, 153.7983, 404.2437,   0.8958,   0.0000],
#         [  0.0000,  13.6495,  94.6383, 400.6388,   0.8943,   0.0000],
#         [124.7054,  88.7559, 232.8170, 402.3645,   0.8831,   0.0000],
#         [224.5188,  64.2595, 333.3858, 402.9164,   0.8819,   0.0000],
#         [309.3857,  23.5012, 393.5341, 183.1679,   0.7933,   0.0000],
#         [172.3384,  42.0756, 244.6108, 181.9800,   0.7423,   0.0000]])
# id: None
# is_track: False
# orig_shape: (408, 612)
# shape: torch.Size([8, 6])
# xywh: tensor([[411.9180, 224.6363, 177.1586, 356.8220],
#         [534.9789, 231.4178, 154.0423, 343.6950],
#         [ 99.8610, 257.6096, 107.8746, 293.2683],
#         [ 47.3191, 207.1441,  94.6383, 386.9893],
#         [178.7612, 245.5602, 108.1115, 313.6086],
#         [278.9523, 233.5880, 108.8671, 338.6568],
#         [351.4599, 103.3345,  84.1483, 159.6667],
#         [208.4746, 112.0278,  72.2724, 139.9045]])
# xywhn: tensor([[0.6731, 0.5506, 0.2895, 0.8746],
#         [0.8741, 0.5672, 0.2517, 0.8424],
#         [0.1632, 0.6314, 0.1763, 0.7188],
#         [0.0773, 0.5077, 0.1546, 0.9485],
#         [0.2921, 0.6019, 0.1767, 0.7686],
#         [0.4558, 0.5725, 0.1779, 0.8300],
#         [0.5743, 0.2533, 0.1375, 0.3913],
#         [0.3406, 0.2746, 0.1181, 0.3429]])
# xyxy: tensor([[323.3387,  46.2252, 500.4973, 403.0473],
#         [457.9577,  59.5703, 612.0000, 403.2654],
#         [ 45.9237, 110.9755, 153.7983, 404.2437],
#         [  0.0000,  13.6495,  94.6383, 400.6388],
#         [124.7054,  88.7559, 232.8170, 402.3645],
#         [224.5188,  64.2595, 333.3858, 402.9164],
#         [309.3857,  23.5012, 393.5341, 183.1679],
#         [172.3384,  42.0756, 244.6108, 181.9800]])
# xyxyn: tensor([[0.5283, 0.1133, 0.8178, 0.9879],
#         [0.7483, 0.1460, 1.0000, 0.9884],
#         [0.0750, 0.2720, 0.2513, 0.9908],
#         [0.0000, 0.0335, 0.1546, 0.9820],
#         [0.2038, 0.2175, 0.3804, 0.9862],
#         [0.3669, 0.1575, 0.5447, 0.9875],
#         [0.5055, 0.0576, 0.6430, 0.4489],
#         [0.2816, 0.1031, 0.3997, 0.4460]])
